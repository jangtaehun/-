# %% [markdown]
# # 202207 이전 데이터셋은 202207부터의 데이터셋과 제공되는 데이터가 다르기 때문에 따로 분리해서 작업

# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def clean_model_data(folder, files):
    df = pd.read_csv(folder + files, encoding='cp949')

    df.drop(['자전거번호', '대여 대여소번호', '대여 대여소명', '대여거치대', '반납일시', '반납대여소명', '반납대여소번호', '반납거치대', '이용시간', '이용거리'], axis=1, inplace=True)

    df = df.dropna()

    df['대여일시'] = pd.to_datetime(df['대여일시'], errors='coerce')
    df = df.dropna(subset=['대여일시'])

    df['대여일자'] = pd.to_datetime(df['대여일시'])
    df['대여일자'] = df['대여일자'].dt.strftime('%Y-%m-%d-%H')

    df.drop(['대여일시'], axis=1, inplace=True)
    return df

def process_bike_model(model_data):
    bike_sum = model_data.groupby('대여일자').size().reset_index(name='대여')
    return bike_sum

# %%
# 모델 학습용 데이터
folder = '/content/drive/MyDrive/공공데이터_자전거/data/bike/'

# 202206~202101
model1 = clean_model_data(folder, '2206.csv')
model2 = clean_model_data(folder, '2205.csv')
model3 = clean_model_data(folder, '2204.csv')
model4 = clean_model_data(folder, '2203.csv')
model5 = clean_model_data(folder, '2202.csv')
model6 = clean_model_data(folder, '2201.csv')
model7 = clean_model_data(folder, '2112.csv')
model8 = clean_model_data(folder, '2111.csv')
model9 = clean_model_data(folder, '2110.csv')
model10 = clean_model_data(folder, '2109.csv')
model11 = clean_model_data(folder, '2108.csv')
model12 = clean_model_data(folder, '2107.csv')
model13 = clean_model_data(folder, '2106.csv')

model14 = clean_model_data(folder, '2105.csv')
model15 = clean_model_data(folder, '2104.csv')
model16 = clean_model_data(folder, '2103.csv')
model17 = clean_model_data(folder, '2102.csv')
model18 = clean_model_data(folder, '2101.csv')
# Out:
# <ipython-input-3-6d43b4473eec>:2: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(folder + files, encoding='cp949')
# <ipython-input-3-6d43b4473eec>:2: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(folder + files, encoding='cp949')
# <ipython-input-3-6d43b4473eec>:2: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(folder + files, encoding='cp949')
# <ipython-input-3-6d43b4473eec>:2: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(folder + files, encoding='cp949')
# <ipython-input-3-6d43b4473eec>:2: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(folder + files, encoding='cp949')

# %%
combined_model = pd.concat([model1, model2, model3, model4, model5, model6, model7, model8, model9, model10, model11, model12, model13, model14, model15, model16, model17, model18], ignore_index=True)
combined_model
# Out:
#                    대여일자
# 0         2022-06-01-06
# 1         2022-06-01-07
# 2         2022-06-01-12
# 3         2022-06-01-21
# 4         2022-06-02-08
# ...                 ...
# 49063770  2021-01-24-20
# 49063771  2021-01-25-12
# 49063772  2021-01-27-14
# 49063773  2021-01-31-14
# 49063774  2021-01-31-15
#
# [49063775 rows x 1 columns]

# %%
model_data = process_bike_model(combined_model)
model_data = model_data.sort_values(by='대여일자', ascending=True)
model_data

# %%
# model_df = model_data[~model_data['대여일자'].str.startswith("2021-05-31")]
model_data.reset_index(drop=True, inplace=True)
model_data

# %%
model_data.to_csv('/content/drive/MyDrive/공공데이터_자전거/data/bike/model_data.csv', index=False)
