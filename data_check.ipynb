# %%
import pandas as pd

pd.options.display.max_columns = 50

# %%
total_data = pd.read_csv('/content/drive/MyDrive/공공데이터_자전거/code/total_raw.csv')
total_data
# Out:
#                       대여일자       대여  기온(°C)  습도(%)  지면온도(°C)  미세먼지     년  월  \
# 0      2021-01-01 00:00:00    388.0    -8.3     66      -6.8     1  2024  1
# 1      2021-01-01 01:00:00    339.0    -8.7     68      -6.9     0  2024  1
# 2      2021-01-01 02:00:00    258.0    -9.1     69      -7.1     1  2024  1
# 3      2021-01-01 03:00:00    204.0    -9.3     70      -7.3     1  2024  1
# 4      2021-01-01 04:00:00    145.0    -9.3     71      -7.5     0  2024  1
# ...                    ...      ...     ...    ...       ...   ...   ... ..
# 28459  2024-05-31 18:00:00  18254.0    21.4     45      27.0     0  2023  5
# 28460  2024-05-31 19:00:00  12292.0    18.7     65      20.9     0  2023  5
# 28461  2024-05-31 21:00:00   9320.0    18.7     67      19.0     0  2023  5
# 28462  2024-05-31 22:00:00   8053.0    18.8     73      19.0     0  2023  5
# 28463  2024-05-31 23:00:00   4877.0    18.4     80      18.8     0  2023  5
#
#         일  시간  요일  계절  바람  공휴일  주중  비  눈  구름
# ...

# %%
total_data.info()

# %%
total_data.isnull().sum().sum()
# Out:
# 0

# %%
total_data = pd.read_csv('/content/drive/MyDrive/공공데이터_자전거/code/analyze_data.csv')
total_data

# %%
total_data = pd.read_csv('/content/drive/MyDrive/공공데이터_자전거/code/no_drop_analyze_data.csv')
total_data

# %%
total_year = total_data.groupby(['년']).count()
total_month = total_data.groupby(['월'])

# %%
conditions = ["남성", "여성" , "기타회원", "대여"]

total_year[conditions].reset_index()
# Out:
#       년    남성    여성  기타회원    대여
# 0  2022  4163  4163  4163  4163
# 1  2023  8372  8372  8372  8372
# 2  2024  3445  3445  3445  3445
